# %% [markdown]
# ## Setup

# %%
import joblib
import pandas as pd
from PIL import Image
from tqdm import tqdm

# %% [markdown]
# ## Image Labels

# %%
train = joblib.load('train_labels.pkl')
test = joblib.load('test_labels.pkl')

# %% [markdown]
# ## Image Directory

# %%
root_path = "/mnt/d/archive"
image = Image.open(root_path+"/"+"images-224/images-224/"+"00000002_000.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=224x224>
